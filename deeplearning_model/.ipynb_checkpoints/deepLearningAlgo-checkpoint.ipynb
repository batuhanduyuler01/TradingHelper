# %%
import sys
sys.path.insert(0, '../../current_work')


import helpers.yFinance_class as yfHelper
import pandas as pd
import data_process_lib as dpl


# Veri Çekme İşlemleri #
# 1 - Tüm data için aynı period ve interval almak istiyoruz.
# use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        #period = "ytd",

# fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        #interval = "1m",

# %%
period = '10y'
interval = '1d'

userInputGaran = 'GARAN.IS'
userInputYapiKredi = 'YKBNK.IS'
userInputBIST = 'XU030.IS'
userInputUSD_TRY = 'TRY=X'
userInputJapanese30 = '^N225'

stockHelperData_0 = yfHelper.yFinance(userInputGaran.upper(), period, interval).getData()
stockHelperData_1 = yfHelper.yFinance(userInputYapiKredi.upper(), period, interval).getData()
stockHelperData_2 = yfHelper.yFinance(userInputUSD_TRY.upper(), period, interval).getData()
stockHelperData_3 = yfHelper.yFinance(userInputBIST.upper(), period, interval).getData()
stockHelperData_4 = yfHelper.yFinance(userInputJapanese30.upper(), period, interval).getData()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
stockHelperData_0 = dpl.obtainLabels(stockHelperData_0)

# %%
dataList = [stockHelperData_0, stockHelperData_1, stockHelperData_2, stockHelperData_3, stockHelperData_4]

# %%
for i, df in enumerate(dataList, 0):
    
    for col_name in df.columns:
        
        
        if col_name == "Date":
            pass
        else:
            df.rename(columns = {f"{col_name}" : f"{col_name}" + f"_{i}"}, inplace = True)
            

            
        #df.columns = [col_name+'_{}'.format(i) for col_name in df.columns]

# %%
dataList[0]
# Out:
#            Date  Open_0  High_0  Low_0  Close_0  Adj Close_0   Volume_0  \
# 0    2012-02-09    6.76    6.98   6.72     6.76     5.656574   78673415
# 1    2012-02-10    6.58    6.80   6.52     6.58     5.505955   68813082
# 2    2012-02-13    6.78    6.80   6.64     6.78     5.673310   48757924
# 3    2012-02-14    6.68    6.82   6.62     6.68     5.589632   57953393
# 4    2012-02-15    6.70    6.80   6.64     6.70     5.606367   44190139
# ...         ...     ...     ...    ...      ...          ...        ...
# 2555 2022-02-02   12.02   12.32  12.02    12.29    12.290000  287602316
# 2556 2022-02-03   12.10   12.17  11.91    11.94    11.940000  156869217
# 2557 2022-02-04   11.95   11.97  11.86    11.93    11.930000   72306695
# 2558 2022-02-07   11.92   11.96  11.81    11.94    11.940000   85793003
# 2559 2022-02-08   11.93   12.08  11.92    12.00    12.000000  136183116
#
#       Label_0
# 0        -1.0
# 1         1.0
# 2        -1.0
# 3         1.0
# 4         1.0
# ...       ...
# 2555     -1.0
# 2556     -1.0
# 2557      1.0
# 2558      1.0
# 2559      1.0
#
# [2560 rows x 8 columns]

# %%
merged_df = dataList[0].copy()
for df in dataList[1:]:
    merged_df = pd.merge(merged_df, df, on = 'Date')

# %%
merged_df
# Out:
#            Date  Open_0  High_0  Low_0  Close_0  Adj Close_0   Volume_0  \
# 2345  27439.990234  27439.990234   79600000
# 2346  27248.869141  27248.869141   77100000
# 2347  27284.519531  27284.519531   76600000
#
# [2348 rows x 32 columns]

# %%
import anotherDataProcessLib as adpl

# %%
scaled_df = adpl.minmaxScaler(merged_df)

# %%
scaled_df
# Out:
#            Date    Open_0    High_0     Low_0   Close_0  Adj Close_0  \
# 0    2012-02-09  0.149560  0.147287  0.175595  0.153846     0.100325
# 1    2012-02-10  0.123167  0.124031  0.145833  0.127219     0.080260
# 2    2012-02-13  0.152493  0.124031  0.163690  0.156805     0.102555
# 3    2012-02-14  0.137830  0.126615  0.160714  0.142012     0.091407
# 4    2012-02-15  0.140762  0.124031  0.163690  0.144970     0.093637
# ...         ...       ...       ...       ...       ...          ...
# 2343 2022-02-02  0.920821  0.837209  0.964286  0.971894     0.984014
# 2344 2022-02-03  0.932551  0.817829  0.947917  0.920118     0.937388
# 2345 2022-02-04  0.910557  0.791990  0.940476  0.918639     0.936056
# 2346 2022-02-07  0.906158  0.790698  0.933036  0.920118     0.937388
# 2347 2022-02-08  0.907625  0.806202  0.949405  0.928994     0.945381
#
#       Volume_0  Label_0    Open_1    High_1  ...     Low_3   Close_3  \
# 0     0.079175     -1.0  0.255509  0.278145  ...  0.489186  0.484518
# 1     0.069252      1.0  0.234583  0.248454  ...  0.479757  0.477076
# 2     0.049069     -1.0  0.262484  0.255306  ...  0.486884  0.487771
# 3     0.058323      1.0  0.243883  0.262157  ...  0.483531  0.479144
# 4     0.044472      1.0  0.243883  0.257590  ...  0.484015  0.481152
# ...        ...      ...       ...       ...  ...       ...       ...
# 2343  0.289436     -1.0  0.953069  1.000000  ...  0.007286  0.006971
# 2344  0.157870     -1.0  1.000000  0.985816  ...  0.006940  0.006621
# 2345  0.072768      1.0  0.927798  0.907801  ...  0.006855  0.006505
# 2346  0.086340      1.0  0.895307  0.897163  ...  0.006597  0.006977
# 2347  0.137052      1.0  0.906137  0.911348  ...  0.007263  0.007089
#
#       Adj Close_3  Volume_3    Open_4    High_4     Low_4   Close_4  \
# 0        0.484518  0.080199  0.032134  0.031795  0.031614  0.031581
# 1        0.477076  0.053338  0.032779  0.031727  0.031807  0.029120
# 2        0.487771  0.049713  0.030249  0.032017  0.031869  0.031444
# 3        0.479144  0.062984  0.031355  0.034177  0.032955  0.033808
# 4        0.481152  0.047510  0.037182  0.044949  0.039016  0.043117
# ...           ...       ...       ...       ...       ...       ...
# 2343     0.006971  0.270021  0.852059  0.856345  0.855579  0.859818
# 2344     0.006621  0.207486  0.853311  0.847129  0.850045  0.846754
# 2345     0.006505  0.180471  0.842784  0.851515  0.846005  0.855634
# 2346     0.006977  0.266306  0.853162  0.847678  0.846424  0.847092
# 2347     0.007089  0.227251  0.852744  0.851752  0.855179  0.848686
#
#       Adj Close_4  Volume_4
# 0        0.031581  0.299563
# 1        0.029120  0.258737
# 2        0.031444  0.213038
# 3        0.033808  0.238071
# 4        0.043117  0.349630
# ...           ...       ...
# 2343     0.859818  0.143145
# 2344     0.846754  0.136257
# 2345     0.855634  0.133737
# 2346     0.847092  0.129536
# 2347     0.848686  0.128696
#
# [2348 rows x 32 columns]

# %%
train, test = adpl.train_test_split(scaled_df)

# %%
n_past = 1
n_future = 1

X_train, y_train = adpl.futureSplitData(train, n_past, n_future, 0)
X_test, y_test = adpl.futureSplitData(test, n_past, n_future, 0)

# %%
X_train, X_test = adpl.reshapeData_X(X_train, X_test)
y_train, y_test = adpl.reshapeData_y(y_train, y_test)

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Masking

model = Sequential()
#model.add(Masking(mask_value=0., input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units = 32, activation = 'relu'))
#model.add(Dropout(.25))
model.add(Dense(1, activation = 'tanh'))
    
model.compile(optimizer='adam', loss = 'mean_squared_error')
model.fit(X_train[:,:,:10], y_train, epochs = 10, batch_size=32)
model.summary()
y_predictions = model.predict(X_test[:,:,:10])
# Out:
# Using TensorFlow backend.
# 2022-02-09 21:26:25.545802: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-09 21:26:25.546933: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.
# Epoch 1/10
# 1877/1877 [==============================] - 1s 598us/step - loss: 0.0819
# Epoch 2/10
# 1877/1877 [==============================] - 0s 104us/step - loss: 0.0107
# Epoch 3/10
# 1877/1877 [==============================] - 0s 100us/step - loss: 0.0082
# Epoch 4/10
# 1877/1877 [==============================] - 0s 100us/step - loss: 0.0042
# Epoch 5/10
# 1877/1877 [==============================] - 0s 100us/step - loss: 0.0017
# Epoch 6/10
# 1877/1877 [==============================] - 0s 100us/step - loss: 0.0012
# Epoch 7/10
# 1877/1877 [==============================] - 0s 102us/step - loss: 0.0012
# Epoch 8/10
# 1877/1877 [==============================] - 0s 104us/step - loss: 0.0012
# Epoch 9/10
# 1877/1877 [==============================] - 0s 100us/step - loss: 0.0011
# Epoch 10/10
# 1877/1877 [==============================] - 0s 101us/step - loss: 0.0011
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 32)                5504
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 5,537
# Trainable params: 5,537
# Non-trainable params: 0
# _________________________________________________________________

# %%
import Metrics
results = Metrics.Metrics(y_predictions, y_test)
print(results.calculate_mse())
# Out:
# [0.9582738]

# %%
from sklearn.metrics import r2_score
print(' R2 degeri:',r2_score(y_test,y_predictions))
# Out:
#  R2 degeri: 0.9649046295174931

# %%
import matplotlib.pyplot as plt
cerceve = plt.figure(figsize=(10,5))
plt.plot(y_test)
plt.plot(y_predictions)
cerceve.suptitle('Long Short Term Memory \n')
plt.ylabel('Closing Price (TL)')
plt.xlabel('Days')
plt.legend(['Actual', 'Prediction'])
plt.show()
